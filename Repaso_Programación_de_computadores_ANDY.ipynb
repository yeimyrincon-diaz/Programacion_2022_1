# %% [markdown]
# Subir archivo .ipynb ejecutado al repositorio individual a mas tardar el 04/05/2022 24:00

# %% [markdown]
# Las Notas del siguiente Repaso seran distribuidas de la siguiente manera.
#
#
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np

# %% [markdown]
# ###1. Se tiene los puntos A y B en el cuadrante positivo
# del plano cartesiano, elabore el algoritmo que permita obtener
# la distancia entre A y B.
# ![image.png](data:image/png;base64,...)
# La entrada de usuario debe ser un elemento tipo tupla =(x,y).
# Aproveche el codigo a continuación para adquirir los datos

# %%
x=()#Inicialización de una variable tipo tupla
y=()
x=tuple((int(input('Ingrese x del punto A: ')),int(input('Ingrese x del punto B: '))))
y=tuple((int(input('Ingrese y del punto A: ')),int(input('Ingrese y del punto B: '))))
num=np.square(x[1]-x[0]) + np.square(y[1]-y[0])
num=np.sqrt(num)
print(num)
#Casting de string hacia los valores que conforman la tupla
#print(type(x))#confirmando el tipo de variable a
#print(type(x[0]))
# Out:
# Ingrese x del punto A: 2
# Ingrese x del punto B: 3
# Ingrese y del punto A: 2
# Ingrese y del punto B: 3
# 1.4142135623730951

# %% [markdown]
# ###2. Algoritmo, que calcule el tiempo de encuentro de 2 vehículos
# que van en sentido opuesto, teniendo como datos la distancia
# inicial que los separa y la velocidad de cada uno.
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Recuerde que la velocidad equivale a Una distancia recorida en una cantidad de tiempo V=D/T
# El usuario debe definir:
#
# Distancia Inicial
#
# Velocidad de cada vehículo
#
# T=D/V

# %%
distancia = int(input('Ingrese Distancia que separa los objetos: '))
velocidad1 = int(input('Ingrese velocidad inicial del objeto a: '))
velocidad2 = int(input('Ingrese velocidad inicial del objeto b: '))
tiempo = distancia/(velocidad1+velocidad2)
print(tiempo,"hora(s)")
#VaT=D-VbT
#VaT+VbT=D
#T(Va+Vb)=D
#T=D/(Va+Vb)
# Out:
# Ingrese Distancia que separa los objetos: 100
# Ingrese velocidad inicial del objeto a: 60
# Ingrese velocidad inicial del objeto b: 40
# 1.0 hora

# %% [markdown]
# ###3. Haga un algoritmo que codifique el mensaje que ingresa el usuario por un aumento en cada caracter de su valor ascii,
# El usuario ingresa tanto el mensaje como la clave de codificación.

# %%
#Recuerde la funcion ord() y chr(), para ir de caracter a ascii y viceversa
mensaje = input('Ingrese el mensaje: ') #esto ya es una cadena (arreglo) de caracteres
clave = int(input('Ingrese la clave de codificación: '))
solucion=[]
for indice in range(0,len(mensaje),1): #range(start 0, stop en el tamaño del mensaje, step de a 1). EL rango crea una lista de cero a n numeros
    #print(mensaje[i]) Llover de yo viera jajajajaja
    #indice son los indices
    # for hace que INDICE tenga el valor de cada uno de los elementos del rango
    ##print(indice)
    cambioaascii = ord(mensaje[indice]) + clave
    ##print(mensaje[indice],ord(mensaje[indice]))
    ##print(cambioaascii)
    cambioaascii = chr(cambioaascii)
    solucion.append(cambioaascii) # append añade el caracter al arreglo de solución
    print(solucion) #imprime la respuesta secuenccial de cada iteración, porque estamos en una iteración
    #indice es igual a la direción de cada casa, cada casa es una letra
    #print(i) # h esta en la dirección 0, h esta guardada en mensaje, las direcciones de mensaje estan guardadas en i
#print(chr(97))
#print(ord('a'))#al valor ascii hay que sumarle el valor de la clave ingresado por el usuario
# Out:
# Ingrese el mensaje: hola
# Ingrese la clave de codificación: 2
# ['j']
# ['j', 'q']
# ['j', 'q', 'n']
# ['j', 'q', 'n', 'c']

# %% [markdown]
# ###4.Escriba un algoritmo que calcule todas las posibles combinaciones entre dos cadena de texto, tanto el numerto de estas.
# Ejemplo:
# ![image.png](data:image/png;base64,...)
#
#
# El usuario debe ingresar las cadena de texto.

# %%
cadena1 = input('Ingresela cadena de texto 1: ')
cadena2 = input('Ingrese la cadena de texto 2: ')
solucion = 0
for i in range(0,len(cadena1),1):
    for i2 in range(0,len(cadena2),1):
      #print(i,i2) #imprime el indice de cada caracter de ambas cadenas
      print(cadena1[i],cadena2[i2])
      solucion = solucion + 1
##solucionOPTIMA = len(cadena1)*len(cadena2)

print(solucion)
# Out:
# Ingresela cadena de texto 1: ho
# Ingrese la cadena de texto 2: gr
# h g
# h r
# o g
# o r
# 4
